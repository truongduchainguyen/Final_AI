# %% [markdown]
# Xây dựng bộ phát hiện đối tượng với thuật toán YOLOv3 được viết bằng thư viện Keras. Thư viện này bao gồm đầy đủ các module: phát hiện đối tượng với pre-trainded model, huấn luyện lại mô hình, phát hiện đối tượng ảnh trên ảnh/video/webcam.
#
# Đầu tiên, ta sẽ khởi tạo Google Colab với sử dụng 1 GPU. Sau đó thực hiện kết nối với Google Drive của tài khoản cá nhân như sau:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# Sau đó, sử dụng git để clone thư mục project từ github của tác giả experiencor với đường dẫn như sau. Lưu ý rằng, ta nên đặt thực project kế bên file jupyter notebook này để tiện thao tác.

# %%
# !git clone https://github.com/experiencor/keras-yolo3.git '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3'
# Out:
# fatal: destination path '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3' already exists and is not an empty directory.

# %% [markdown]
# Sau đó tiến hành cài đặt các thư viện cần thiết để có thể sử dụng được keras-yolo3. Đây là bước thực hiện quan trọng vì thông thường các thư viện sẽ sử dụng các thư viện bên thứ 3 với các phiên bản cố định. Do đó, để đảm bảo thư viện keras-yolo3 sử dụng trơn tru thì ta sẽ cài đặt các thư viện kèm theo trong file requirements.txt.

# %%
# !pip install -r '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/requirements.txt'
# Out:
# Requirement already satisfied: absl-py==0.9.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: astor==0.8.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/requirements.txt (line 2)) (0.8.1)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting google-pasta==0.1.8
#   Downloading https://files.pythonhosted.org/packages/c3/fd/1e86bc4837cc9a3a5faf3db9b1854aa04ad35b5f381f9648fbe81a6f94e4/google_pasta-0.1.8-py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 2.8MB/s
# Collecting grpcio==1.26.0
#   Downloading https://files.pythonhosted.org/packages/17/8f/f79c5c174bebece41f824dd7b1ba98da45dc2d4c373b38ac6a7f6a5acb5e/grpcio-1.26.0-cp36-cp36m-manylinux2010_x86_64.whl (2.4MB)
#      |████████████████████████████████| 2.4MB 8.8MB/s
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/requirements.txt (line 6)) (2.10.0)
# Collecting Keras==2.3.1
#   Downloading https://files.pythonhosted.org/packages/ad/fd/6bfe87920d7f4fd475acd28500a42482b6b84479832bdc0fe9e589a60ceb/Keras-2.3.1-py2.py3-none-any.whl (377kB)
#      |████████████████████████████████| 378kB 32.7MB/s
# Collecting Keras-Applications==1.0.8
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 4.4MB/s
# Collecting Keras-Preprocessing==1.1.0
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
#      |████████████████████████████████| 51kB 5.0MB/s
# Collecting Markdown==3.1.1
#   Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
#      |████████████████████████████████| 92kB 7.8MB/s
# Collecting numpy==1.18.1
#   Downloading https://files.pythonhosted.org/packages/62/20/4d43e141b5bc426ba38274933ef8e76e85c7adea2c321ecf9ebf7421cedf/numpy-1.18.1-cp36-cp36m-manylinux1_x86_64.whl (20.1MB)
#      |████████████████████████████████| 20.2MB 7.3MB/s
# Requirement already satisfied: opencv-contrib-python==4.1.2.30 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/requirements.txt (line 12)) (4.1.2.30)
# Collecting opt-einsum==3.1.0
#   Downloading https://files.pythonhosted.org/packages/b8/83/755bd5324777875e9dff19c2e59daec837d0378c09196634524a3d7269ac/opt_einsum-3.1.0.tar.gz (69kB)
#      |████████████████████████████████| 71kB 7.7MB/s
# Collecting protobuf==3.11.2
#   Downloading https://files.pythonhosted.org/packages/ca/ac/838c8c8a5f33a58132dd2ad2a30329f6ae1614a9f56ffb79eaaf71a9d156/protobuf-3.11.2-cp36-cp36m-manylinux1_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 37.5MB/s
# Collecting PyYAML==5.3
#   Downloading https://files.pythonhosted.org/packages/3d/d9/ea9816aea31beeadccd03f1f8b625ecf8f645bd66744484d162d84803ce5/PyYAML-5.3.tar.gz (268kB)
#      |████████████████████████████████| 276kB 38.0MB/s
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/requirements.txt (line 16)) (1.4.1)
# Collecting six==1.14.0
#   Downloading https://files.pythonhosted.org/packages/65/eb/1f97cb97bfc2390a276969c6fae16075da282f5058082d4cb10c6c5c1dba/six-1.14.0-py2.py3-none-any.whl
# Collecting tensorboard==1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 37.6MB/s
# Collecting tensorflow==1.15.0
#   Downloading https://files.pythonhosted.org/packages/3f/98/5a99af92fb911d7a88a0005ad55005f35b4c1ba8d75fba02df726cd936e6/tensorflow-1.15.0-cp36-cp36m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 40kB/s
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 34.1MB/s
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/requirements.txt (line 21)) (1.1.0)
# Requirement already satisfied: tqdm==4.41.1 in /usr/local/lib/python3.6/dist-packages (from -r /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/requirements.txt (line 22)) (4.41.1)
# Collecting Werkzeug==0.16.0
#   Downloading https://files.pythonhosted.org/packages/ce/42/3aeda98f96e85fd26180534d36570e4d18108d62ae36f87694b476b83d6f/Werkzeug-0.16.0-py2.py3-none-any.whl (327kB)
#      |████████████████████████████████| 327kB 40.2MB/s
# Collecting wrapt==1.11.2
#   Downloading https://files.pythonhosted.org/packages/23/84/323c2415280bc4fc880ac5050dddfb3c8062c2552b34c2e512eb4aa68f79/wrapt-1.11.2.tar.gz
# Requirement already satisfied: setuptools>=36 in /usr/local/lib/python3.6/dist-packages (from Markdown==3.1.1->-r /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/requirements.txt (line 10)) (49.2.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.15.0->-r /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/requirements.txt (line 18)) (0.34.2)
# Building wheels for collected packages: gast, opt-einsum, PyYAML, wrapt
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=f23d93e2c220e0f360dc79789aad3976e4c269ecc72e93af947b7af8a3ab1247
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
#   Building wheel for opt-einsum (setup.py) ... done
#   Created wheel for opt-einsum: filename=opt_einsum-3.1.0-cp36-none-any.whl size=61682 sha256=5b75d6e15f101750a74401b484433672b6625f006a68cb6e2b9311decd2da5ba
#   Stored in directory: /root/.cache/pip/wheels/2c/b1/94/43d03e130b929aae7ba3f8d15cbd7bc0d1cb5bb38a5c721833
#   Building wheel for PyYAML (setup.py) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.3-cp36-cp36m-linux_x86_64.whl size=44229 sha256=9cf36ca788c72965f44fde0b6f26c99a43ed32f8e022602fe0eaaf2821015ccf
#   Stored in directory: /root/.cache/pip/wheels/e4/76/4d/a95b8dd7b452b69e8ed4f68b69e1b55e12c9c9624dd962b191
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.11.2-cp36-cp36m-linux_x86_64.whl size=67517 sha256=3d87525804b4f4f8c4e926246cf97384fae02cbcc11fa6735a3d2bf5fe24803f
#   Stored in directory: /root/.cache/pip/wheels/d7/de/2e/efa132238792efb6459a96e85916ef8597fcb3d2ae51590dfd
# Successfully built gast opt-einsum PyYAML wrapt
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement six~=1.15.0, but you'll have six 1.14.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: gast, six, google-pasta, grpcio, PyYAML, numpy, Keras-Preprocessing, Keras-Applications, Keras, Markdown, opt-einsum, protobuf, Werkzeug, tensorboard, wrapt, tensorflow-estimator, tensorflow
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Found existing installation: google-pasta 0.2.0
#     Uninstalling google-pasta-0.2.0:
#       Successfully uninstalled google-pasta-0.2.0
#   Found existing installation: grpcio 1.30.0
#     Uninstalling grpcio-1.30.0:
#       Successfully uninstalled grpcio-1.30.0
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Found existing installation: Keras-Preprocessing 1.1.2
#     Uninstalling Keras-Preprocessing-1.1.2:
#       Successfully uninstalled Keras-Preprocessing-1.1.2
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
#   Found existing installation: Markdown 3.2.2
#     Uninstalling Markdown-3.2.2:
#       Successfully uninstalled Markdown-3.2.2
#   Found existing installation: opt-einsum 3.3.0
#     Uninstalling opt-einsum-3.3.0:
#       Successfully uninstalled opt-einsum-3.3.0
#   Found existing installation: protobuf 3.12.4
#     Uninstalling protobuf-3.12.4:
#       Successfully uninstalled protobuf-3.12.4
#   Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: wrapt 1.12.1
#     Uninstalling wrapt-1.12.1:
#       Successfully uninstalled wrapt-1.12.1
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# Successfully installed Keras-2.3.1 Keras-Applications-1.0.8 Keras-Preprocessing-1.1.0 Markdown-3.1.1 PyYAML-5.3 Werkzeug-0.16.0 gast-0.2.2 google-pasta-0.1.8 grpcio-1.26.0 numpy-1.18.1 opt-einsum-3.1.0 protobuf-3.11.2 six-1.14.0 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1 wrapt-1.11.2

# %% [markdown]
# Thử nghiệm với pretrained model của tác giả thuật toán YOLO.
#
# File mô hình huấn luyện sẵn được đặt ở đường dẫn sau https://pjreddie.com/media/files/yolov3.weights
# Lưu ý là file mô hình cần được đặt trong thư mục gốc của thư viện để tiện cho việc thực hiện.

# %%
# !wget 'https://pjreddie.com/media/files/yolov3.weights' -O '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/yolov3.weights'
# Out:
# --2020-08-06 02:29:41--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/yolov3.weights’
#
# /content/gdrive/My  100%[===================>] 236.52M   413KB/s    in 10m 42s
#
# 2020-08-06 02:40:25 (377 KB/s) - ‘/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/yolov3.weights’ saved [248007048/248007048]

# %%
#Check GPU
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# Một file khác cũng rất quan trọng của các mô hình huấn luyện học sâu nói chung và YOLO nói riêng là file cấu hình (config) các tham số khi huấn luyện.
#
# Trong thư viện này, file config được đặt trong thư mục /zoo. Ví dụ như config_raccoon.json. Các tham số cơ bản của file config như:
# - Đường dẫn đến thư mục train, validation (mặc định chia tỉ lệ train:validation = 8:2 nếu không có tham số gắn sẵn)
# - GPU sử dụng để huấn luyện
# - File pretrained cho tập image net backend.h5
# - Learning rate
# - Batch size
#
# Sau khi đã cấu hình file config, ta sẽ tiến hành huấn luyện:

# %%
# !python '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/train.py' -c '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/config/config_city.json'
# Out:
# Using TensorFlow backend.
# 2020-08-06 02:40:35.720292: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-08-06 02:40:35.727526: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-08-06 02:40:35.727802: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3036bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-06 02:40:35.727844: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-06 02:40:35.730471: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-06 02:40:35.786479: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 02:40:35.787304: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3036d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-08-06 02:40:35.787349: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-08-06 02:40:35.787558: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 02:40:35.788332: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-08-06 02:40:35.788720: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-06 02:40:35.795682: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-06 02:40:35.797299: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-06 02:40:35.797837: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-06 02:40:35.799984: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-06 02:40:35.801153: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-06 02:40:35.811162: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-06 02:40:35.811357: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 02:40:35.812161: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 02:40:35.812894: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-06 02:40:35.812978: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-06 02:40:35.814491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-06 02:40:35.814533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-08-06 02:40:35.814560: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-08-06 02:40:35.814761: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 02:40:35.815591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 02:40:35.816365: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10297 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/train.py:26: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# valid_annot_folder not exists. Spliting the trainining set.
# Seen labels: 	{'car': 674, 'motorbike': 2927}
#
# Given labels: 	['car', 'motorbike']
#
# Training on: 	['car', 'motorbike']
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/yolo.py:26: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/yolo.py:151: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
#
# Loading pretrained weights.
#
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:998: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:431: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:438: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/100
# 2020-08-06 02:43:17.184690: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 154140672 exceeds 10% of system memory.
# 2020-08-06 02:43:17.551925: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 154140672 exceeds 10% of system memory.
# 2020-08-06 02:43:18.093992: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-06 02:43:22.273872: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# WARNING:tensorflow:From /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/callbacks.py:19: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# 2020-08-06 02:45:27.995048: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.19GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# resizing:  288 288
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
#  - 200s - loss: 16.3167 - yolo_layer_1_loss: 0.6037 - yolo_layer_2_loss: 3.5597 - yolo_layer_3_loss: 12.1532
#
# Epoch 00001: loss improved from inf to 16.31668, saving model to /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/city.h5
# Epoch 2/100
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
#  - 83s - loss: 17.1044 - yolo_layer_1_loss: 0.5753 - yolo_layer_2_loss: 3.8298 - yolo_layer_3_loss: 12.6993
#
# Epoch 00002: loss did not improve from 16.31668
# Epoch 3/100
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  416 416
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
#  - 82s - loss: 16.6437 - yolo_layer_1_loss: 0.6648 - yolo_layer_2_loss: 3.4246 - yolo_layer_3_loss: 12.5543
#
# Epoch 00003: loss did not improve from 16.31668
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 4/100
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
#  - 78s - loss: 16.5457 - yolo_layer_1_loss: 0.3646 - yolo_layer_2_loss: 3.4664 - yolo_layer_3_loss: 12.7148
#
# Epoch 00004: loss did not improve from 16.31668
# Epoch 5/100
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
#  - 82s - loss: 16.1127 - yolo_layer_1_loss: 0.4966 - yolo_layer_2_loss: 3.4286 - yolo_layer_3_loss: 12.1875
#
# Epoch 00005: loss improved from 16.31668 to 16.11273, saving model to /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/city.h5
# Epoch 6/100
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  288 288
#  - 79s - loss: 15.7162 - yolo_layer_1_loss: 0.5131 - yolo_layer_2_loss: 3.0997 - yolo_layer_3_loss: 12.1035
#
# Epoch 00006: loss improved from 16.11273 to 15.71619, saving model to /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/city.h5
# Epoch 7/100
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  448 448
# resizing:  352 352
# resizing:  288 288
# resizing:  416 416
#  - 91s - loss: 16.2643 - yolo_layer_1_loss: 0.5727 - yolo_layer_2_loss: 3.8991 - yolo_layer_3_loss: 11.7925
#
# Epoch 00007: loss did not improve from 15.71619
# Epoch 8/100
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  320 320
#  - 86s - loss: 15.9225 - yolo_layer_1_loss: 0.4623 - yolo_layer_2_loss: 3.5234 - yolo_layer_3_loss: 11.9368
#
# Epoch 00008: loss did not improve from 15.71619
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 9/100
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
# resizing:  416 416
# resizing:  384 384
# resizing:  288 288
# resizing:  384 384
# resizing:  352 352
# resizing:  384 384
#  - 82s - loss: 15.9763 - yolo_layer_1_loss: 0.4925 - yolo_layer_2_loss: 3.6064 - yolo_layer_3_loss: 11.8773
#
# Epoch 00009: loss did not improve from 15.71619
# Epoch 10/100
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
# resizing:  288 288
#  - 81s - loss: 15.7695 - yolo_layer_1_loss: 0.5163 - yolo_layer_2_loss: 3.5226 - yolo_layer_3_loss: 11.7305
#
# Epoch 00010: loss did not improve from 15.71619
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 11/100
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  288 288
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  288 288
# resizing:  416 416
#  - 75s - loss: 15.4590 - yolo_layer_1_loss: 0.3506 - yolo_layer_2_loss: 2.9599 - yolo_layer_3_loss: 12.1485
#
# Epoch 00011: loss improved from 15.71619 to 15.45901, saving model to /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/city.h5
# Epoch 12/100
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
#  - 80s - loss: 15.5287 - yolo_layer_1_loss: 0.3975 - yolo_layer_2_loss: 3.0551 - yolo_layer_3_loss: 12.0760
#
# Epoch 00012: loss did not improve from 15.45901
# Epoch 13/100
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  352 352
# resizing:  352 352
#  - 79s - loss: 15.6284 - yolo_layer_1_loss: 0.4124 - yolo_layer_2_loss: 3.3412 - yolo_layer_3_loss: 11.8748
#
# Epoch 00013: loss did not improve from 15.45901
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Epoch 14/100
# resizing:  448 448
# resizing:  320 320
# resizing:  320 320
# resizing:  448 448
# resizing:  352 352
# resizing:  352 352
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
#  - 81s - loss: 15.6247 - yolo_layer_1_loss: 0.4814 - yolo_layer_2_loss: 3.2982 - yolo_layer_3_loss: 11.8450
#
# Epoch 00014: loss did not improve from 15.45901
# Epoch 15/100
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  352 352
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
# resizing:  416 416
#  - 83s - loss: 15.5974 - yolo_layer_1_loss: 0.5600 - yolo_layer_2_loss: 3.3793 - yolo_layer_3_loss: 11.6581
#
# Epoch 00015: loss did not improve from 15.45901
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# Epoch 16/100
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
# resizing:  416 416
# resizing:  416 416
# resizing:  352 352
# resizing:  384 384
# resizing:  352 352
#  - 83s - loss: 15.8576 - yolo_layer_1_loss: 0.5408 - yolo_layer_2_loss: 3.3963 - yolo_layer_3_loss: 11.9205
#
# Epoch 00016: loss did not improve from 15.45901
# Epoch 17/100
# resizing:  320 320
# resizing:  448 448
# resizing:  288 288
# resizing:  320 320
# resizing:  416 416
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  352 352
#  - 79s - loss: 15.3399 - yolo_layer_1_loss: 0.3726 - yolo_layer_2_loss: 2.9354 - yolo_layer_3_loss: 12.0319
#
# Epoch 00017: loss improved from 15.45901 to 15.33994, saving model to /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/city.h5
# Epoch 18/100
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
#  - 81s - loss: 15.6672 - yolo_layer_1_loss: 0.4587 - yolo_layer_2_loss: 3.0878 - yolo_layer_3_loss: 12.1207
#
# Epoch 00018: loss did not improve from 15.33994
# Epoch 19/100
# resizing:  416 416
# resizing:  288 288
# resizing:  416 416
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  448 448
#  - 79s - loss: 15.5261 - yolo_layer_1_loss: 0.3747 - yolo_layer_2_loss: 3.0443 - yolo_layer_3_loss: 12.1071
#
# Epoch 00019: loss did not improve from 15.33994
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# Epoch 20/100
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
#  - 88s - loss: 15.9192 - yolo_layer_1_loss: 0.6182 - yolo_layer_2_loss: 3.5281 - yolo_layer_3_loss: 11.7729
#
# Epoch 00020: loss did not improve from 15.33994
# Epoch 21/100
# resizing:  288 288
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  384 384
# resizing:  384 384
# resizing:  416 416
#  - 79s - loss: 15.3741 - yolo_layer_1_loss: 0.3799 - yolo_layer_2_loss: 3.0463 - yolo_layer_3_loss: 11.9479
#
# Epoch 00021: loss did not improve from 15.33994
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# Epoch 22/100
# resizing:  416 416
# resizing:  448 448
# resizing:  416 416
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  384 384
# resizing:  448 448
# resizing:  320 320
#  - 99s - loss: 16.6994 - yolo_layer_1_loss: 0.7571 - yolo_layer_2_loss: 4.2761 - yolo_layer_3_loss: 11.6662
#
# Epoch 00022: loss did not improve from 15.33994
# Epoch 23/100
# resizing:  288 288
# resizing:  288 288
# resizing:  384 384
# resizing:  448 448
# resizing:  384 384
# resizing:  320 320
# resizing:  416 416
# resizing:  416 416
# resizing:  320 320
#  - 87s - loss: 15.7581 - yolo_layer_1_loss: 0.5121 - yolo_layer_2_loss: 3.4647 - yolo_layer_3_loss: 11.7814
#
# Epoch 00023: loss did not improve from 15.33994
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 9.999999092680235e-13.
# Epoch 24/100
# resizing:  288 288
# resizing:  320 320
# resizing:  352 352
# resizing:  320 320
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
#  - 72s - loss: 14.8613 - yolo_layer_1_loss: 0.2655 - yolo_layer_2_loss: 2.5986 - yolo_layer_3_loss: 11.9972
#
# Epoch 00024: loss improved from 15.33994 to 14.86130, saving model to /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/city.h5
# Epoch 25/100
# resizing:  448 448
# resizing:  352 352
# resizing:  384 384
# resizing:  448 448
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  352 352
# resizing:  320 320
#  - 83s - loss: 15.9354 - yolo_layer_1_loss: 0.4749 - yolo_layer_2_loss: 3.2662 - yolo_layer_3_loss: 12.1944
#
# Epoch 00025: loss did not improve from 14.86130
# Epoch 26/100
# resizing:  416 416
# resizing:  448 448
# resizing:  288 288
# resizing:  352 352
# resizing:  352 352
# resizing:  320 320
# resizing:  288 288
# resizing:  288 288
# resizing:  352 352
#  - 81s - loss: 15.5852 - yolo_layer_1_loss: 0.5093 - yolo_layer_2_loss: 3.1813 - yolo_layer_3_loss: 11.8946
#
# Epoch 00026: loss did not improve from 14.86130
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 9.9999988758398e-14.
# Epoch 27/100
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  288 288
# resizing:  416 416
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  448 448
#  - 90s - loss: 16.1551 - yolo_layer_1_loss: 0.6077 - yolo_layer_2_loss: 3.6108 - yolo_layer_3_loss: 11.9365
#
# Epoch 00027: loss did not improve from 14.86130
# Epoch 28/100
# resizing:  448 448
# resizing:  448 448
# resizing:  320 320
# resizing:  448 448
# resizing:  384 384
# resizing:  352 352
# resizing:  352 352
# resizing:  384 384
# resizing:  384 384
# resizing:  352 352
#  - 92s - loss: 16.6044 - yolo_layer_1_loss: 0.6648 - yolo_layer_2_loss: 3.8866 - yolo_layer_3_loss: 12.0530
#
# Epoch 00028: loss did not improve from 14.86130
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 9.999999146890344e-15.
# Epoch 29/100
# resizing:  384 384
# resizing:  352 352
# resizing:  320 320
# resizing:  352 352
# resizing:  416 416
# resizing:  288 288
# resizing:  384 384
# resizing:  288 288
# resizing:  320 320
#  - 83s - loss: 15.6265 - yolo_layer_1_loss: 0.4355 - yolo_layer_2_loss: 3.4733 - yolo_layer_3_loss: 11.7177
#
# Epoch 00029: loss did not improve from 14.86130
# Epoch 30/100
# resizing:  384 384
# resizing:  320 320
# resizing:  288 288
# resizing:  320 320
# resizing:  320 320
# resizing:  320 320
# resizing:  384 384
#  - 72s - loss: 15.5586 - yolo_layer_1_loss: 0.3602 - yolo_layer_2_loss: 2.8907 - yolo_layer_3_loss: 12.3077
#
# Epoch 00030: loss did not improve from 14.86130
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 9.999998977483753e-16.
# Epoch 31/100
# resizing:  448 448
# resizing:  384 384
# resizing:  384 384
# resizing:  384 384
# resizing:  320 320
# resizing:  384 384
# resizing:  352 352
# resizing:  448 448
# resizing:  416 416
# resizing:  320 320
#  - 88s - loss: 15.6969 - yolo_layer_1_loss: 0.4271 - yolo_layer_2_loss: 3.5438 - yolo_layer_3_loss: 11.7260
#
# Epoch 00031: loss did not improve from 14.86130
# Epoch 00031: early stopping
# car: 0.8408
# motorbike: 0.8529
# mAP: 0.8468

# %% [markdown]
# Sau khi quá trình huấn luyện kết thúc, hệ thống sẽ lưu mô hình city.h5 trong thư mục của máy ảo colab. Ta có thể sửa lại mã nguồn của thư viện để các file mô hình và file trung gian đặt trong thư mục của thư viện cho gọn gàng.
#
# Sau đó, ta sẽ tiến hành thử nghiệm mô hình đã huấn luyện trên ảnh mẫu lấy từ mạng internet hoặc thư mục ảnh validation/train.
#
# Dưới đây là sử dụng lại hình ảnh trong bộ thư viện train để valuate thử

# %%
# !python '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/predict.py' -c '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/config/config_city.json' -i '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/JPEGImages/img(200).jpg'
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-08-06 03:29:25.269171: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-06 03:29:25.272258: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:29:25.272980: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-08-06 03:29:25.273299: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-06 03:29:25.277921: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-06 03:29:25.279121: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-06 03:29:25.279501: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-06 03:29:25.281161: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-06 03:29:25.282393: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-06 03:29:25.291056: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-06 03:29:25.291209: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:29:25.292021: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:29:25.292718: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-06 03:29:25.293208: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-08-06 03:29:25.298723: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-08-06 03:29:25.298931: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x28e0d80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-06 03:29:25.298965: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-06 03:29:25.352272: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:29:25.353138: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x28e0f40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-08-06 03:29:25.353199: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-08-06 03:29:25.353503: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:29:25.354145: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-08-06 03:29:25.354231: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-06 03:29:25.354302: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-06 03:29:25.354358: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-06 03:29:25.354407: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-06 03:29:25.354465: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-06 03:29:25.354522: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-06 03:29:25.354572: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-06 03:29:25.354706: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:29:25.355578: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:29:25.356204: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-06 03:29:25.356289: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-06 03:29:25.357715: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-06 03:29:25.357749: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-08-06 03:29:25.357767: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-08-06 03:29:25.357912: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:29:25.358651: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:29:25.359320: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-08-06 03:29:25.359383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10748 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# /content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/JPEGImages/img(200).jpg
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2020-08-06 03:30:57.781598: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-06 03:30:58.568749: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0

# %% [markdown]
# Tiếp theo chúng ta sử dụng video nằm ngoài training data để valuate model
#
# Link download video: https://drive.google.com/file/d/1xNCHifyCupOu5LJS81BmonToTrAYvPt7/view?usp=sharing

# %%
# !python '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/predict.py' -c '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/config/config_city.json' -i '/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/evalvid3.mp4'
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-08-06 03:31:04.778804: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-06 03:31:04.781826: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:31:04.782630: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-08-06 03:31:04.782923: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-06 03:31:04.784586: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-06 03:31:04.785786: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-06 03:31:04.786173: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-06 03:31:04.787874: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-06 03:31:04.789069: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-06 03:31:04.793459: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-06 03:31:04.793610: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:31:04.794406: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:31:04.795087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-06 03:31:04.795490: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-08-06 03:31:04.800933: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-08-06 03:31:04.801193: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x30f6d80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-06 03:31:04.801229: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-06 03:31:04.849288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:31:04.850132: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x30f6f40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-08-06 03:31:04.850164: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-08-06 03:31:04.850390: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:31:04.851054: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-08-06 03:31:04.851133: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-06 03:31:04.851180: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2020-08-06 03:31:04.851232: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2020-08-06 03:31:04.851296: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2020-08-06 03:31:04.851342: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2020-08-06 03:31:04.851391: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2020-08-06 03:31:04.851436: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-06 03:31:04.851563: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:31:04.852300: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:31:04.852921: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-08-06 03:31:04.852999: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2020-08-06 03:31:04.854525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-08-06 03:31:04.854560: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-08-06 03:31:04.854578: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-08-06 03:31:04.854769: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:31:04.855584: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-06 03:31:04.856312: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-08-06 03:31:04.856365: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10748 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# OpenCV: FFMPEG: tag 0x4745504d/'MPEG' is not supported with codec id 2 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
#   0% 0/13500 [00:00<?, ?it/s]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2020-08-06 03:31:16.764786: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-08-06 03:31:17.532431: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 100% 13500/13500 [31:01<00:00,  7.25it/s]

# %%
# Di chuyen video den Drive ca nhan de tien cho viec download
# !mv "/content/output/evalvid3.mp4" "/content/gdrive/My Drive/AI/Learning/Collab/YoloV3/traffic_dataset/Output"
